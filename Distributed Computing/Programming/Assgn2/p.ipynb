# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import time

# %%
x = [4, 9, 16, 25, 36]

# num messages
y1 = [
    (5.53333 + 5.18333 + 5.6)/3,
    (15.7037+15.7407+15.7333)/3,
    (29.6375+29.5625+29.6833)/3,
    (47.3333+47.392+47.376)/3,
    (68.8611+68.7704+69.2019)/3
]
y2 = [
    (11.5167+11.6667+11.4667)/3,
    (19.7037+19.8593+19.8593)/3,
    (27.7917+27.8625+27.8375)/3,
    (35.8907+35.7307+36.1733)/3,
    (43.8759+44.0204+43.7389)/3
]

z = [5, 10, 15, 20, 25]

# throughput
t1 = [
    0.876911,
    0.850357,
    0.774116,
    0.737138,
    0.715815
]
t2 = [
    0.922062,
    0.881811,
    0.829471,
    0.785597,
    0.769357,
]

# %%
plt.plot(x, y1, label='Roucairol-Carvalho')
plt.plot(x, y2, label='Maekawa')
plt.xlabel('Number of processes')
plt.ylabel('Number of messages')
plt.legend()
plt.show()

# %%
plt.plot(z, t1, label='Roucairol-Carvalho')
plt.plot(z, t2, label='Maekawa')
plt.xlabel('System Load')
plt.ylabel('Throughput')
plt.legend()
plt.show()
